# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

workersTips = pd.read_csv("workerstips.csv")
sb.scatterplot(workersTips['total_bill'],workersTips['tip'])

plt.ylabel("Tips")
plt.show()
# Out:
# C:\Users\Aidan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
workersTips = pd.read_csv("workerstips.csv")

tips = sns.load_dataset("tips")
tips.head()
sns.scatterplot(data=tips, x="total_bill", y="tip", size="size", sizes=(10, 300), legend="auto")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tipsData = sns.load_dataset("tips")
sns.barplot(data=tipsData, x="day", y="tip")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
tipsData = sns.load_dataset("tips")
sns.boxplot(data=tipsData, x="day", y="tip", hue="time")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
flights = sns.load_dataset("flights")
flights.head()

passPerYear = flights.groupby('year').sum()
sns.lineplot(x=passPerYear.index, y="passengers", data=passPerYear,)
sns.lineplot(x="year", y="passengers", data=flights,)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
titanicData = sns.load_dataset("titanic")
titanicData.head()


count = titanicData.groupby(['class', 'sex', 'survived']).count().reset_index()

sns.catplot(data=count, x="class", y="who", col="survived", kind="bar", hue="sex")
plt.show()
